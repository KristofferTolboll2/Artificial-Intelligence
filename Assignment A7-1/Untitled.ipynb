# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('http://bit.ly/imdbratings')

# %%
df.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
df.isna().sum()
#Almost no none values
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
#Actually more explicit rating, higher imdb rating, pg-13 and R is among the highest
sns.catplot(x='content_rating', y='star_rating', data=df, jitter=False)

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.catplot(x='content_rating', y='star_rating', data=df, jitter=False)

# %%
df.genre.nunique()
# 16 unique genres
# Out:
# 16

# %%
df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
sns.distplot(df['star_rating'], kde=False, bins=50);
#very few are rated very high

# %%
df.nlargest(20, 'star_rating')
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
top20 = df.nlargest(20, 'star_rating')

# %%
top20.loc[:5, :]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
# 5          8.9              12 Angry Men      NOT RATED   Drama        96
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %%
sns.relplot(x="duration", y="star_rating", data=df);

# %% [markdown]
# **Not really any correlation between duration and star rating,. Though a tendency, that very short movies, are ofent not that successfull**

# %%
sns.scatterplot(x='duration',y='star_rating',hue='content_rating',size='genre',data=df)
#Crime is very popular and rated R aswell

# %%
from sklearn.cluster import MeanShift as ms

# %%
df.fillna('hey')
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
cols = df.loc[:, ['star_rating', 'duration']]

# %%
plt.scatter(cols['star_rating'], cols['duration'])

# %%
#longer movies higer review.. in general, very short movies, don't have high rating

# %%
sns.lmplot(x='duration', y='star_rating', data=df)

# %%
plt.scatter(df['star_rating'], df['duration'], hue=df['genre'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-5b1056144e31> in <module>
# ----> 1 plt.scatter(df['star_rating'], df['duration'], hue=df['genre'])
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
# ...

# %%
# !pip3 install altair
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/01/55/0bb2226e34f21fa549c3f4557b4f154a5632f61132a969da17c95ca8eab9/altair-4.1.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/bb/71/8f53bdbcbc67c912b888b40def255767e475402e9df64050019149b1a943/pandas-1.0.3-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/3d/fc/4763e5f17ac6e7e7d55f377cde859ca1c5d5ac624441ab45315bc578aa9e/numpy-1.18.3-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# ...

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
colors =['green', 'red', 'blue', 'yellow', 'purple', 'black', 'orange', 'brown', 'pink', 'honeydew', 'navy', 'eggplant', 'gold', 'copper', 'silver', 'lavender']
genres = list(df['genre'].unique())

# %%
vectorizer = np.vectorize(lambda x: {genres.pop(): colors.pop()})
colors
# Out:
# ['green',
#  'red',
#  'blue',
#  'yellow',
#  'purple',
#  'black',
#  'orange',
#  'brown',
#  'pink',
#  'honeydew',
#  'navy',
#  'eggplant',
#  'gold',
#  'copper',
#  'silver',
#  'lavender']

# %%
sns.lmplot(x='star_rating', y='duration', hue='genre', data=df)

# %%
sns.clustermap(data=df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in calculated_linkage(self)
#     625         try:
# --> 626             return self._calculate_linkage_fastcluster()
#     627         except ImportError:
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in _calculate_linkage_fastcluster(self)
#     606     def _calculate_linkage_fastcluster(self):
# --> 607         import fastcluster
#     608         # Fastcluster has a memory-saving vectorized version, but only
#
# ModuleNotFoundError: No module named 'fastcluster'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-166-b219f127e8bb> in <module>
# ----> 1 sns.clustermap(data=df)
#
# ...

# %%
df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
heatmap_data = df.loc[:, ['star_rating', 'duration', 'genre']]

# %%
heatmap_data
# Out:
#      star_rating  duration      genre
# 0            9.3       142      Crime
# 1            9.2       175      Crime
# 2            9.1       200      Crime
# 3            9.0       152     Action
# 4            8.9       154      Crime
# ..           ...       ...        ...
# 974          7.4       116     Comedy
# 975          7.4       118  Adventure
# 976          7.4       138     Action
# 977          7.4       114     Horror
# 978          7.4       126      Crime
#
# [979 rows x 3 columns]

# %%
test = pd.isnull(np.array([np.nan, 0], dtype=float))

# %%
sns.heatmap(df.loc[:, ['star_rating', 'duration']])

# %%
#I will use Sklearn's KNN classifier to find out, how a given movie is rated

# %%
df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
y = df['content_rating']
X = df.drop('content_rating', axis=1)

# %%
# Categorical boolean mask
categorical_feature_mask = X.dtypes==object
# filter categorical columns using mask and turn it into a list
categorical_cols = X.columns[categorical_feature_mask].tolist()

# %%
X[categorical_cols] = X[categorical_cols].apply(lambda col: le.fit_transform(col))

# %%
y.isna().sum()
# Out:
# 0

# %%
X
# Out:
#      star_rating  title  genre  duration  actors_list
# 0            9.3    865      5       142          872
# 1            9.2    755      5       175          620
# 2            9.1    756      5       200           23
# 3            9.0    729      0       152          173
# 4            8.9    559      5       154          499
# ..           ...    ...    ...       ...          ...
# 974          7.4    913      4       116          257
# 975          7.4     81      1       118          663
# 976          7.4    458      0       138          791
# 977          7.4    549     11       114          480
# 978          7.4    938      5       126          157
#
# [976 rows x 5 columns]

# %%
df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.5, random_state=42)

# %%
print(X_test)
# Out:
#      star_rating  title  genre  duration  actors_list
# 200          8.1    414      5       101           26
# 542          7.8      0      4        95          965
# 174          8.2    537      6        83           77
# 469          7.8    912      0       130          573
# 66           8.4    491      4       156          854
# ..           ...    ...    ...       ...          ...
# 526          7.8    971      6       138          838
# 336          8.0    426      1       127          855
# 915          7.5     82      5       106          325
# 15           8.7    365      1       169          634
# 3            9.0    729      0       152          173
#
# [488 rows x 5 columns]

# %%
print(y_test)
# Out:
# 200           PG
# 542        PG-13
# 174    NOT RATED
# 469            R
# 66     NOT RATED
#          ...
# 526      UNRATED
# 336           PG
# 915        NC-17
# 15         PG-13
# 3          PG-13
# Name: content_rating, Length: 488, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
k_range = range(1,26)
scores = {} #dict
scores_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_test, y_train)
    y_pred = knn.predict(X_test)
    scores[k] = metrics.accuracy_score(y_test, y_pred)
    scores_list.append(metrics.accuracy_score(y_test, y_pred))

# %%
plt.plot(scores_list)

# %% [markdown]
# # Analysis
# The results where actually pretty poor for this model so far.
# I wanted to show, that some models also can produce bad results, and then give an analysis, on why this can occur.
# ### KNN
# In this given example we could argue, that a model, like KNN would not produce the best results given our dataset. KNN works better for classification, where we have similar data based on given features, and we can some from our matplotlib and seaborn graphs, that actually a lot of our features did not have a high coherrence
