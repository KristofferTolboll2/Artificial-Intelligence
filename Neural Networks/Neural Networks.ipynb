# %% [markdown]
# Recap: https://towardsdatascience.com/everything-you-need-to-know-about-neural-networks-and-backpropagation-machine-learning-made-easy-e5285bc2be3a
#
# Neural networks is a mathematical mode, which is used in Machine Learning.
# The principle is based on the same anatomy of the human brai.
# The brain is made out of many neurons, which accept input stimuli from sensory or other neurons thorugh **dendrites**
#
# If the stimuli is strong enough it will fire a signal to the neuron. Furthermore each node has a weight, which derterminets the importance of each specific neuron in respect to the other neurons.
# which determintes how much each neuron matters in regards to the others.
#
#
# ***
# **three different types of neurons:**
#
# There are three primary types of neuron: sensory neurons, motor neurons, and interneurons.
# ...
#
#
# ***
# **General principles:**
# Repetition - to facilitate transition of impulses betweens neurones,
#
# correct fundamentals - practise the *right* things
#
# authentic enviroment - Learning specifics related to the enviroment

# %% [markdown]
# From an software engineering point of view, we can implement a neural network, as as **graph of nodes** in a network.
#
# Each of the nodes send signals to it's neighbors
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
